# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoArenasI/52524/blob/main/prueba_maestria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#paso 2 verificar el entorno

print ("phyton :", sys.version )
print ("pandas:", pd.__version__)
# Out:
# phyton : 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# pandas: 2.2.2

# %%
#cargar data

ds = pd.read_csv('data1.csv')

# %%
print(ds.head())
# Out:
#   ClienteID     Genero  Jubilado Socio Dependientes  Permanencia  \
# 0   QM-5876   Femenino         0    Si           Si           23
# 1   AX-2277   Femenino         0    No           No           32
# 2   JT-9442   Femenino         0    No           No           11
# 3   PH-0979  Masculino         0    Si           Si           69
# 4   SV-3067   Femenino         0    Si           No           68
#
#   ServicioTelefonico MultiplesLineas ServicioInternet      SeguridadOnline  \
# 0                 Si              No               No  No internet service
# 1                 Si              No               No  No internet service
# 2                 Si              No               No  No internet service
# 3                 Si              Si      Fiber optic                   No
# 4                 Si              No              DSL                   Si
#
#    ... DispositivosProtegidos       SoporteTecnico          StreamingTV  \
# ...

# %%
print(ds.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ClienteID               7043 non-null   object
#  1   Genero                  7043 non-null   object
#  2   Jubilado                7043 non-null   int64
#  3   Socio                   7043 non-null   object
#  4   Dependientes            7043 non-null   object
#  5   Permanencia             7043 non-null   int64
#  6   ServicioTelefonico      7043 non-null   object
#  7   MultiplesLineas         7043 non-null   object
#  8   ServicioInternet        7043 non-null   object
#  9   SeguridadOnline         7043 non-null   object
#  10  RespaldoOnline          7043 non-null   object
#  11  DispositivosProtegidos  7043 non-null   object
#  12  SoporteTecnico          7043 non-null   object
#  13  StreamingTV             7043 non-null   object
# ...

# %%
print(" valores nulos: ", ds.isnull().sum())
# Out:
#  valores nulos:  ClienteID                 0
# Genero                    0
# Jubilado                  0
# Socio                     0
# Dependientes              0
# Permanencia               0
# ServicioTelefonico        0
# MultiplesLineas           0
# ServicioInternet          0
# SeguridadOnline           0
# RespaldoOnline            0
# DispositivosProtegidos    0
# SoporteTecnico            0
# StreamingTV               0
# StreamingMovies           0
# Contrato                  0
# Facturacion               0
# MetodoPago                0
# CargoMensual              0
# CargoTotal                0
# Cancelacion               0
# dtype: int64

# %%
ds. describe (include = 'all').T
# Out:
#                          count unique             top  freq       mean  \
# ClienteID                 7043   7041         CN-3721     2        NaN
# Genero                    7043      2       Masculino  3555        NaN
# Jubilado                7043.0    NaN             NaN   NaN   0.162147
# Socio                     7043      2              No  3641        NaN
# Dependientes              7043      2              No  4933        NaN
# Permanencia             7043.0    NaN             NaN   NaN  32.371149
# ServicioTelefonico        7043      2              Si  6361        NaN
# MultiplesLineas           7043      3              No  3390        NaN
# ServicioInternet          7043      3     Fiber optic  3096        NaN
# SeguridadOnline           7043      3              No  3498        NaN
# RespaldoOnline            7043      3              No  3088        NaN
# DispositivosProtegidos    7043      3              No  3095        NaN
# ...
